# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import glob,os, csv
import matplotlib.pyplot as plt
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.problems import *
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from graph.network import Network
from graph.sfc_set import SFC_SET

# %%
names = [ "cogent", "conus", "nsf"]
areas = ["center", "rural", "uniform", "urban"]
requests = [10, 20, 30] 
i_s = [0, 1, 2, 3, 4]

folder_path = 'vnf\graph\output'
os.makedirs(folder_path, exist_ok=True)
for name in names:
    for area in areas:
        for request in requests:
            for i in i_s:
                name_folder = name+"_"+area+"_"+str(i)
                network = Network("D:/HỌC ĐI BẠN TRẺ/Lab training/NSGA2/vnf/dataset/" + name_folder + "/input.txt")
                sfc_set = SFC_SET("D:/HỌC ĐI BẠN TRẺ/Lab training/NSGA2/vnf/dataset/" + name_folder + "/request" + str(request) + ".txt")
                rs = []
                problem = get_problem("nfv", network, sfc_set)
                algorithm = NSGA2(pop_size=100)
                res = minimize(problem,
                                algorithm,
                                ('n_gen', 100),
                                seed=1,
                                verbose=True)                
                file_path = os.path.join(folder_path, f'{name_folder}_request_{str(request)}_result.csv')
                result = {}
                for i in res.F:
                    result['fitness_1'] = i[0]
                    result['fitness_2'] = i[1]
                    with open(file_path, 'a') as file:
                        fieldnames = ['fitness_1', 'fitness_2']
                        writer = csv.DictWriter(file, fieldnames=fieldnames)
                        writer.writerow(result)
# Out:
# sum server cost:  72208
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |      100 |      4 |             - |             -
#      2 |      200 |      4 |  0.0521892938 |             f
#      3 |      300 |      7 |  0.1062088764 |         ideal
#      4 |      400 |      7 |  0.0164726693 |             f
#      5 |      500 |      8 |  0.1607884109 |         ideal
#      6 |      600 |     10 |  0.0192322289 |             f
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\HỌC ĐI BẠN TRẺ\Lab training\NSGA2\vnf\nsga2.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/d%3A/H%E1%BB%8CC%20%C4%90I%20B%E1%BA%A0N%20TR%E1%BA%BA/Lab%20training/NSGA2/vnf/nsga2.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a> problem = get_problem("nfv", network, sfc_set)
#      <a href='vscode-notebook-cell:/d%3A/H%E1%BB%8CC%20%C4%90I%20B%E1%BA%A0N%20TR%E1%BA%BA/Lab%20training/NSGA2/vnf/nsga2.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> algorithm = NSGA2(pop_size=100)
# ---> <a href='vscode-notebook-cell:/d%3A/H%E1%BB%8CC%20%C4%90I%20B%E1%BA%A0N%20TR%E1%BA%BA/Lab%20training/NSGA2/vnf/nsga2.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a> res = minimize(problem,
#      <a href='vscode-notebook-cell:/d%3A/H%E1%BB%8CC%20%C4%90I%20B%E1%BA%A0N%20TR%E1%BA%BA/Lab%20training/NSGA2/vnf/nsga2.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a>                 algorithm,
#      <a href='vscode-notebook-cell:/d%3A/H%E1%BB%8CC%20%C4%90I%20B%E1%BA%A0N%20TR%E1%BA%BA/Lab%20training/NSGA2/vnf/nsga2.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a>                 ('n_gen', 100),
#      <a href='vscode-notebook-cell:/d%3A/H%E1%BB%8CC%20%C4%90I%20B%E1%BA%A0N%20TR%E1%BA%BA/Lab%20training/NSGA2/vnf/nsga2.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a>                 seed=1,
#      <a href='vscode-notebook-cell:/d%3A/H%E1%BB%8CC%20%C4%90I%20B%E1%BA%A0N%20TR%E1%BA%BA/Lab%20training/NSGA2/vnf/nsga2.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a>                 verbose=True)
#      <a href='vscode-notebook-cell:/d%3A/H%E1%BB%8CC%20%C4%90I%20B%E1%BA%A0N%20TR%E1%BA%BA/Lab%20training/NSGA2/vnf/nsga2.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a> file_path = os.path.join(folder_path, f'{name_folder}_request_{str(request)}_result.csv')
#      <a href='vscode-notebook-cell:/d%3A/H%E1%BB%8CC%20%C4%90I%20B%E1%BA%A0N%20TR%E1%BA%BA/Lab%20training/NSGA2/vnf/nsga2.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a> result = {}
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\optimize.py:67, in minimize(problem, algorithm, termination, copy_algorithm, copy_termination, **kwargs)
#      64     algorithm.setup(problem, **kwargs)
#      66 # actually execute the algorithm
# ---> 67 res = algorithm.run()
#      69 # store the deep copied algorithm in the result object
#      70 res.algorithm = algorithm
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\core\algorithm.py:141, in Algorithm.run(self)
#     139 def run(self):
#     140     while self.has_next():
# --> 141         self.next()
#     142     return self.result()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\core\algorithm.py:161, in Algorithm.next(self)
#     159 # call the advance with them after evaluation
#     160 if infills is not None:
# --> 161     self.evaluator.eval(self.problem, infills, algorithm=self)
#     162     self.advance(infills=infills)
#     164 # if the algorithm does not follow the infill-advance scheme just call advance
#     165 else:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\core\evaluator.py:69, in Evaluator.eval(self, problem, pop, skip_already_evaluated, evaluate_values_of, count_evals, **kwargs)
#      65 # evaluate the solutions (if there are any)
#      66 if len(I) > 0:
#      67
#      68     # do the actual evaluation - call the sub-function to set the corresponding values to the population
# ---> 69     self._eval(problem, pop[I], evaluate_values_of, **kwargs)
#      71 # update the function evaluation counter
#      72 if count_evals:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\core\evaluator.py:90, in Evaluator._eval(self, problem, pop, evaluate_values_of, **kwargs)
#      87 X = pop.get("X")
#      89 # call the problem to evaluate the solutions
# ---> 90 out = problem.evaluate(X, return_values_of=evaluate_values_of, return_as_dictionary=True, **kwargs)
#      92 # for each of the attributes set it to the problem
#      93 for key, val in out.items():
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\core\problem.py:187, in Problem.evaluate(self, X, return_values_of, return_as_dictionary, *args, **kwargs)
#     184     only_single_value = not (isinstance(X, list) or isinstance(X, np.ndarray))
#     186 # this is where the actual evaluation takes place
# --> 187 _out = self.do(X, return_values_of, *args, **kwargs)
#     189 out = {}
#     190 for k, v in _out.items():
#     191
#     192     # copy it to a numpy array (it might be one of jax at this point)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\core\problem.py:229, in Problem.do(self, X, return_values_of, *args, **kwargs)
#     227     self._evaluate_elementwise(X, out, *args, **kwargs)
#     228 else:
# --> 229     self._evaluate_vectorized(X, out, *args, **kwargs)
#     231 # finally format the output dictionary
#     232 out = self._format_dict(out, len(X), return_values_of)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\core\problem.py:237, in Problem._evaluate_vectorized(self, X, out, *args, **kwargs)
#     236 def _evaluate_vectorized(self, X, out, *args, **kwargs):
# --> 237     self._evaluate(X, out, *args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\problems\nfv\nfv.py:60, in NFV._evaluate(self, x, out, *args, **kwargs)
#      58         break
#      59     ser = self.remove_servers_invalid(ser, sfc, network_copy)
# ---> 60     self.find_path_dijkstra(ser, network_copy, sfc, pos, individual)
#      61 if check == False:
#      62     break
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\problems\nfv\nfv.py:131, in NFV.find_path_dijkstra(self, end_nodes, network_copy, sfc, pos, individual)
#     126 distances[network_copy.N[start_id]] = 0
#     128 # for end_node in end_nodes:
#     129     # print("end node: ", end_node.id)
#     130 # time.sleep(10)
# --> 131 previous_nodes = {node: None for node in network_copy.N.values()}
#     132 unvisited_nodes = [(0, sfc.path[-1])]
#     133 while unvisited_nodes:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\problems\nfv\nfv.py:131, in <dictcomp>(.0)
#     126 distances[network_copy.N[start_id]] = 0
#     128 # for end_node in end_nodes:
#     129     # print("end node: ", end_node.id)
#     130 # time.sleep(10)
# --> 131 previous_nodes = {node: None for node in network_copy.N.values()}
#     132 unvisited_nodes = [(0, sfc.path[-1])]
#     133 while unvisited_nodes:
#
# KeyboardInterrupt:

# %%
import glob,os, csv
import matplotlib.pyplot as plt
from pymoo.algorithms.moo.age import AGEMOEA
from pymoo.problems import *
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from graph.network import Network
from graph.sfc_set import SFC_SET

names = [ "cogent", "conus", "nsf"]
areas = ["center", "rural", "uniform", "urban"]
requests = [10, 20, 30] 
i_s = [0, 1, 2, 3, 4]

folder_path = 'vnf\graph\output_age'
os.makedirs(folder_path, exist_ok=True)
for name in names:
    for area in areas:
        for request in requests:
            for i in i_s:
                name_folder = name+"_"+area+"_"+str(i)
                network = Network("D:/HỌC ĐI BẠN TRẺ/Lab training/NSGA2/vnf/dataset/" + name_folder + "/input.txt")
                sfc_set = SFC_SET("D:/HỌC ĐI BẠN TRẺ/Lab training/NSGA2/vnf/dataset/" + name_folder + "/request" + str(request) + ".txt")
                rs = []
                problem = get_problem("nfv", network, sfc_set)
                algorithm = AGEMOEA(pop_size=100)
                res = minimize(problem,
                                algorithm,
                                ('n_gen', 100),
                                seed=1,
                                verbose=True)                
                file_path = os.path.join(folder_path, f'{name_folder}_request_{str(request)}_result.csv')
                result = {}
                for i in res.F:
                    result['fitness_1'] = i[0]
                    result['fitness_2'] = i[1]
                    with open(file_path, 'a') as file:
                        fieldnames = ['fitness_1', 'fitness_2']
                        writer = csv.DictWriter(file, fieldnames=fieldnames)
                        writer.writerow(result)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymoo\algorithms\moo\age.py